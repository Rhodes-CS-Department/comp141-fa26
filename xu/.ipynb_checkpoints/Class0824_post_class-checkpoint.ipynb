# %% [markdown]
# # Any Questions About Previous Topics:
# - Key idea of programming: input -> machine -> output
# - Printing
#     - Printing multiple things at once
# - Comments
# - Assignment statements (variable = "Hello")
# - Variables
#     - Variable Naming
# - Data Types
#     - Integers
#     - Floats
#     - Strings

# %% [markdown]
# ## Key ideas about programming
# - Most every program you write does the following things:
#
#   - Step 1: Receive input.
#   - Step 2: Process the input (with some sort of algorithm).
#   - Step 3: Produce output.
#
# - Programs execute line by line, top to bottom (with a cell).
#
# - In a notebook, press Shift-Enter to run a cell.

# %% [markdown]
# ## `print` function
#
# - Syntax: `print(______, ______, ...)`
# - Outputs anything inside the parentheses to the screen.  Multiple items will be separated by spaces.
#
# ## Data types
#
# - Three main ones:
#   - integers (whole numbers), known as `int`s
#   - numbers with a decimal point, known as `float`s
#   - sequences of letters/numbers/symbols/punctuation, known as strings (in Python: `str`)
#
# - Strings must always be surrounded by single or double quotes!

# %%
# Practice printing each kind of data type.

print(3)      # prints an int
print(-3.5)   # prints a float
print("Hello world!")  # prints a string
print("Here is an integer:", 78, "and here is a float:", 0.003)
# Out:
# 3
# -3.5
# Hello world!
# Here is an integer: 78 and here is a float: 0.003

# %% [markdown]
# ## Variables
#
# - The job of a **variable** is to hold a **value**.  Variables can hold values of any data type.
# - The most common way to give a variable a value is with an **assignment statement**.
#
# *`variable = value`*
#
# - The variable *must* go on the left side, and the value *must* go on the right.

# %%
# Practice printing each kind of data type.

num_bananas = 3
num_watermelons = 2.5
name = "Bill Gates"
print(name, "is eating", num_bananas, "bananas and", num_watermelons, "watermelons.")
# Out:
# Bill Gates is eating 3 bananas and 2.5 watermelons.

# %% [markdown]
# ## Math
#
# - For numbers: addition (`+`), subtraction (`-`), multiplication (`*`), division (`/`), exponents (`**`)
#
# - For strings: addition (`+`)

# %%
# Math examples
a = 5
b = 3
c = a + b
d = a - b
e = a + b * c
f = (a + b) * c
print(a, b, c, d, e, f)
# Out:
# 5 3 8 2 29 64

# %% [markdown]
# - Also remainder (`%`) and integer division (`//`)

# %%
# Remainder example:
print("The remainder of 13 divided by 5 is", 13 % 5)

# Or, same thing:
remainder = 13 % 5
print("The remainder of 13 divided by 5 is", remainder)
# Out:
# The remainder of 13 divided by 5 is 3
# The remainder of 13 divided by 5 is 3

# %%
# Integer division example:
print("13 divided by 5 exactly is", 13 / 5)
print("But the integer portion is", 13 // 5)

# Or, equivalently:
quotient = 13 // 5
print("But the integer portion is", quotient)
# Out:
# 13 divided by 5 exactly is 2.6
# But the integer portion is 2
# But the integer portion is 2

# %% [markdown]
# - Remainders and integer division are often used to convert distances and times.
# - These operations are also used to check whether a number is even or odd, or if one number is divisible by another number.

# %%
a = 10 % 2
print(a)
# Out:
# 0

# %%
# String addition (better known as string concatenation)
a = "Rhodes"
b = "College"
c = a + b
print(c)
# Out:
# RhodesCollege

# %%
print(a + " " + b) 

d = a + " " + b
print(d) # Same thing
# Out:
# Rhodes College
# Rhodes College

# %%
# You can only add a number to a number, or a string to a string.

print(3 + 4)      # ok
print("3" + "4")  # also ok
print("3" + 4)    # not ok
# Out:
# 7
# 34
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       1 # You can only add a number to a number, or a string to a string.
#       2
#       3 print(3 + 4)      # ok
#       4 print("3" + "4")  # also ok
# ----> 5 print("3" + 4)    # not ok
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Data Types
#
# Categorize value in memory
#
#    - Integers(int) - whole numbers; may be negative
#    - Floats(float) - any number with a decimal point; may be negative
#    - Strings (str) - Any sequence of letters, numbers, or punctuation.
#
# Some operations behave differently depending on data type
#
# Sometimes you can convert between data types (like converting the user input to a float in Lab 0!)

# %%
#Example showing the differences between integer and string variables
a = 5
b = 7
print(a / b)
print(a//b)
print(a % b)
print(a * 5)
# Out:
# 0.7142857142857143
# 0
# 5
# 25

# %%
a = "a"
b = "7"
print(a+b)
print(int(a) * 5)
# Out:
# a7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 4
#       1 a = "a"
#       2 b = "7"
#       3 print(a+b)
# ----> 4 print(int(a) * 5)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# A variable in Python can refer to items of any type
#
# **If you’re using the same variable name for different uses, Python will assume you mean the most recent use**

# %%
x = 90
print(x)
x = "Take me to your leader"
print(x)
x = 90
print(x)
# Out:
# 90
# Take me to your leader
# 90

# %% [markdown]
# ## Functions
# **Function:** A part of a program that takes an input (the **argument(s)**) and does something with it
#
# Example: the `print` function takes the input and displays it.
#
# You use functions (**call** them) by printing their name and putting the argument in between the parentheses, like so: `print('Hello, World')`

# %% [markdown]
# ## Nested function call:
#
# You can pass functions into other functions! In this case, the value returned by the inner function is the argument of the outer function.
#
# general format: function1(function2(argument))
#
#    - value returned by function2 is passed to function1
#    - Type conversion only works if item is valid numeric value, otherwise, throws exception

# %% [markdown]
# ## Review excercise 1: My Favorite Number
#
# Write a Python program that:
#
# 1. Includes a comment describing what the program does.
# 2. Creates these three variables:
#     - name, containing your name as a string
#     - favorite_number, containing your favorite integer
#     - lucky_decimal, containing a decimal number
# 3. Prints all three variables.
# 4. Uses one print() statement to print multiple things together.
#
# Example Output:
#
# ```
# My name is Hong
# My favorite number is 7
# My lucky decimal is 3.14
# ```

# %%
name = "Hong"
favorite_number = 6
lucky_decimal = 0.235323
print("My name is", name)
print("My fn", favorite_number)
print("My ld", lucky_decimal)
print("My name is", name, "\nMy fn", favorite_number, "\nMy ld", lucky_decimal)
print("My name is "+ name+ "\nMy fn "+ str(favorite_number)+ "\nMy ld "+ str(lucky_decimal))
# Out:
# My name is Hong
# My fn 6
# My ld 0.235323
# My name is Hong
# My fn 6
# My ld 0.235323
# My name is Hong
# My fn 6
# My ld 0.235323

# %% [markdown]
# ## Review excercise 2:
#
# Write a Python program that creates and prints a fictional student profile.
#
# 1. Add a comment at the top describing the program.
# 2. Create variables for:
#     - the student’s name—a string
#     - the student’s age—an integer
#     - the student’s height in feet—a float
#     - the student’s intended major—a string
# 5. Use meaningful variable names.
# 6. Print the information as complete sentences.
# 7. Increase the student’s age by 1 and print their age next year.
# 8. In at least one print() statement, print multiple items separated by commas.
#
# Example output:
# ```
# Meet Alex, who is 18 years old.
# Alex is 5.8 feet tall and intends to major in computer science.
# Next year, Alex will be 19 years old.
# ```

# %% [markdown]
# # Practice
# ### You are driving along an empty highway in South Carolina, keeping up with the flow of traffic, but going 74 miles-per-hour in a 60 miles-per-hour zone\*. Assume that the fine is \$15 for every mile per hour over the limit.
#
# \* This example in no way reflects anything that may or may not have happened to your professor north of Charleston.
#
# ### Which of the following programs will print the correct fine?
#
# ```python
# # These are three completely separate programs.
#
# # Program 1
# speed = 74
# limit = 60
# print(fine)
# fine = (speed - limit) * 15
#
# # Program 2
# speed = 74
# limit = 60
# fine = over * 15
# over = (speed - limit)
# print(fine)
#
# # Program 3
# limit = 60
# speed = 74
# fine = (speed - limit) * 15
# print(fine)
# ```

# %%
# %reset -f
# Do the examples above in your head first, before running them.  (Ignore the %reset line above.)

# %% [markdown]
# ### What is the output of the following program? (this is one continuous program).
#
# ```python
# a = 4
# b = 5
# print(a, b)
# a = 3
# b = a
# print(a, b)
# a = b + 1
# a = a + 1
# print(a, b)
# a = 1
# b = 2
# a = b
# b = a
# print(a, b)
# ```

# %% [markdown]
# ## Performing Calculation Practice
#
# #### Fast food prices
#
# * You’re working at a fast food restaurant where a burger costs `$3.99` and French fries cost `$1.99`.
# * Write a program (in the cell below) that uses 2 variables to store these two prices.
# * Your program should then print out the cost of buying 2 burgers and 3 fries.
# * If you finish early, make your program add in 9.25% sales tax.
#
# Don't forget to test your code!

# %% [markdown]
# # New Stuff
# ## Reading Numbers with the input Function
#
#    - input function always returns a string
#
# Python has built-in functions to convert between data types
#
#    - int(item) converts item to an int
#    - float(item) converts item to a float
#
# Input from Keyboard:
#
#    - For integers: variable = int(input("Prompt"))
#    - For ﬂoats: variable = float(input("Prompt"))
#    - For strings: variable = input("Prompt")

# %%
#Prompt the user for their age
age = int(input("How old are you? "))
name = input("What is your name? ")

print("My name is", name , "You will be", age+1, "on your next birthday.")
# Out:
# How old are you?  31
# What is your name?  Hong
# My name is Hong You will be 32 on your next birthday.

# %%
# Comments
# age = 18
# print(age)

# %%
# Write your program here.
